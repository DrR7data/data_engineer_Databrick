# %%
# %run ../setup

# %%
#catalog_name = "iter_20"
#schema_name = "bronze_track_raw"
#volume_name = "myfiles"

# %%
#spark.sql("USE SCHEMA bronze_track_raw;")

# %%
df = spark.read.option("inferSchema", "true").csv(f"s3://{buckett}/track_raw.csv", header=False)
df.head()

# %%
df.write.format("delta").mode("overwrite").save(f"s3://{buckett}/track_delta_lake/bronze/track_raw", header=True)

# %%
spark.sql(f"""
SELECT * from delta.`s3://{buckett}/track_delta_lake/bronze/track_raw`
""").display()

# %%
spark.sql(f"""
DESCRIBE HISTORY delta.`s3://{buckett}/track_delta_lake/bronze/track_raw`
""").display()

# %%
#df_limpio.write.mode("overwrite").csv(f"s3://{buckett}/iter_nac20_c.csv",  header=True)

# %%
#df = spark.read.option("inferSchema", "true").csv(f"s3://{buckett}/iter_nac20_c.csv", header=True)

# %%
df.display(20)

# %%
#spark.sql(f"DROP TABLE iter_nac20_ra ; ")

# %%
#spark.sql(f""" DROP TABLE DELTA.`s3://{buckett}/bronze_i/iter_delta_raw`;""").show()
