# %%
import os

raw_data_volume ="/Volumes/workspace/bronze/my-volume/library"

# Print out a list of directories in our raw_data volume and a few files from those directories
for table in os.listdir(raw_data_volume):
  print(table + "/")
  for file in os.listdir(raw_data_volume + table)[:3]:
    print("  " + file)
  print("  ...")

# %%
# %sql
select * from read_files("/Volumes/workspace/bronze/my-volume/library/library.csv", format => "csv") limit 10

# %%
# %sql
select * from read_files("/Volumes/workspace/bronze/my-volume/track/track_raw.csv", format => "csv") limit 10

# %%
# %sql
select * from read_files("/Volumes/workspace/bronze/my-volume/who/whc-sites-2018-small.csv", format => "csv") limit 10

# %%
# %sql
SHOW VOLUMES;
