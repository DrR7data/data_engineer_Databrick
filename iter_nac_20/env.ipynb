# %%
S3_DELTA_LAKE_ITER = 's3://databric-rrr/iter_20'
S3_DELTA_LAKE_ITER_BRONZE = f"{AWS_DELTA_LAKE_ITER}/bronze_i"
S3_DELTA_LAKE_ITER_SILVER = f"{AWS_DELTA_LAKE_ITER}/silver_i"
S3_DELTA_LAKE_ITER_GOLD = f"{AWS_DELTA_LAKE_ITER}/gold_i"
