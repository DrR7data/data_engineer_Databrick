# %%
# %sql 
CREATE catalog if not EXISTS iter_20;
CREATE SCHEMA IF NOT EXISTS iter_20.bronze_iter;
use catalog iter_20;
use schema bronze_iter;

# %%
import conf as g

# %%
iter20= spark.read.csv(f"s3://{buckertt}/iter_nac20.csv", header=True, inferSchema=True)
iter20.show(5, truncate=False)

# %%
iter20.write.mode("overwrite").saveAsTable('iter_nac20_raw')

# %%
spark.sql(f'''
DROP table if exists iter_nac20_ra
 ''').show()

# %%
spark.sql(f'''
SELECT * from iter_nac20_raw limit 100
 ''').show(20, truncate=True)

# %%
df = spark.sql(f'''
SELECT * from iter_nac20_raw limit 100
 ''')
df.show(20, truncate=True)
df.printSchema()

# %%
df = spark.sql(f'''
SELECT * from iter_nac20_raw limit 100
 ''')
df.show(20, truncate=True)
df.printSchema()

# %%
spark.sql(f'''
CREATE TABLE IF NOT EXISTS iter_nac20_raw()
USING delta LOCATION "s3://{buckett}/{iter_2}/iter_nac20/";
 ''')
