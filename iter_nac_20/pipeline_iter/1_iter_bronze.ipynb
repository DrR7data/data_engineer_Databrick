# %%
# %run ../setup

# %%
spark.sql("USE SCHEMA bronze_iter;")

# %%
df = spark.read.option("inferSchema", "true").csv(f"s3://{buckett}/iter_nac20.csv", header=True)
df.head()

# %%
df_limpio.display(20)

# %%
df.display(20)

# %%
df.printSchema()

# %%
iter20= spark.read.csv(f"s3://{buckett}/iter_nac20.csv", header=True, inferSchema=True)
iter20.display(20)

# %%
spark.sql(f"""
    CREATE TABLE IF NOT EXISTS iter_delta_raw
    USING delta LOCATION 's3://{buckett}/bronze_i/iter_delta_raw';
""")
spark.sql(f"""
    COPY INTO iter_delta_raw 
    FROM 's3://{buckett}/iter_nac20.csv' 
    FILEFORMAT = csv 
    FORMAT_OPTIONS ('header' = 'true', 'inferSchema' = 'true')
    COPY_OPTIONS ('mergeSchema' = 'true');
""")
spark.sql(f"""
    SELECT * from iter_delta_raw limit 5;
""").display()

#'inferSchema' = 'true'

# %%
spark.sql(f"""
    SELECT * from iter_delta_raw limit 5 ;
""").display()

# %%
spark.sql(f"SELECT * FROM delta.`s3://{buckett}/bronze_i/iter_delta_raw` limit 10").display()

# %%
#spark.sql(f"DROP TABLE iter_nac20_ra ; ")

# %%
#spark.sql(f""" DROP TABLE DELTA.`s3://{buckett}/bronze_i/iter_delta_raw`;""").show()

# %%
track_p = "s3://{buckett}/bronze_i/iter_delta_raw"
dbutils.fs.rm(f"{track_p}", recurse=True)

# %%
# %sql
CREATE TABLE IF NOT EXISTS iter_delta_raw ( 
)
USING delta LOCATION 's3://{buckett}/bronze_i/iter_delta_raw';

COPY INTO  iter_delta_raw FROM 's3://{buckett}/iter_nac20.csv' FILEFORMAT = csv COPY_OPTIONS ('mergeSchema' = 'true');
SELECT * from iter_delta_raw ;

# %%
#iter20.write.mode("overwrite").saveAsTable(f"s3://{buckett}/bronze_i/iter_delta_raw")

# %%
iter20.write.mode("overwrite").saveAsTable('iter_nac20_raw')

# %%
spark.sql(f'''
SELECT * from iter_nac20_raw limit 5
 ''').display()
