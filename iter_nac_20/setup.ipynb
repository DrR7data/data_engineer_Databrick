# %%
# %sql 
CREATE catalog if not EXISTS iter_20;
CREATE SCHEMA IF NOT EXISTS iter_20.bronze_iter;
CREATE SCHEMA IF NOT EXISTS iter_20.silver_iter;
CREATE SCHEMA IF NOT EXISTS iter_20.gold_iter;
use catalog iter_20;

# %%
buckett = "databric-rrr/iter_20"
